# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
from numpy import genfromtxt

# %%
# data_path = '/content/gdrive/Dataset/iris.csv'
# data_path = 'iris.csv'
data_path = 'iris.csv'
my_data = genfromtxt(data_path, delimiter=',') # numpy array n_samples x (feature+1)


data_path_reg = 'diabetes.csv'
my_data_reg = genfromtxt(data_path_reg, delimiter=',')

# %%
my_data.shape
# Out:
# (150, 5)

# %%
#my_data.shape
print(type(my_data))
print(my_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (150, 5)

# %%
data_iris = my_data.tolist() # 2d list
#for i in range(len(data)):    #whole 150 values of iris.csv
for i in range(5):
  print(data_iris[i])
type(data_iris)


data_diabetes = my_data_reg.tolist() # 2d list
#for i in range(len(data)):    #whole 150 values of iris.csv
for i in range(5):
  print(data_diabetes[i])
type(data_diabetes)
# Out:
# [5.1, 3.5, 1.4, 0.2, 0.0]
# [4.9, 3.0, 1.4, 0.2, 0.0]
# [4.7, 3.2, 1.3, 0.2, 0.0]
# [4.6, 3.1, 1.5, 0.2, 0.0]
# [5.0, 3.6, 1.4, 0.2, 0.0]
# [0.0380759064334241, 0.0506801187398187, 0.0616962065186885, 0.0218723549949558, -0.0442234984244464, -0.0348207628376986, -0.0434008456520269, -0.00259226199818282, 0.0199084208763183, -0.0176461251598052, 151.0]
# [-0.00188201652779104, -0.044641636506989, -0.0514740612388061, -0.0263278347173518, -0.00844872411121698, -0.019163339748222, 0.0744115640787594, -0.0394933828740919, -0.0683297436244215, -0.09220404962683, 75.0]
# [0.0852989062966783, 0.0506801187398187, 0.0444512133365941, -0.00567061055493425, -0.0455994512826475, -0.0341944659141195, -0.0323559322397657, -0.00259226199818282, 0.00286377051894013, -0.0259303389894746, 141.0]
# ...

# %%
# from sklearn import datasets
# import numpy as np
# iris = datasets.load_iris()
# X = iris.data[:, :2]
# y = (iris.target != 0) * 1

# %%
# print(X.shape)
# print(y.shape)
# print(y)

# %%
#classification
print('Classificcation')
import random
from operator import itemgetter

train_set = []
val_set = []
test_set = []
#count = 0
for sample in data_iris:
    
    R = random.random()
    if R >= 0 and R <= 0.7:
        train_set.append(sample)
        
    elif R > 0.7 and R <= 0.85:
        val_set.append(sample)
       
    else:
        test_set.append(sample)
    
    #count = count+1
    #print(count)



#L = []
val_acc_list = []

#for K in range(5, 8, 2):
K = 1   #change value of K
corr = 0
for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
    count_0 = 0
    count_1 = 0
    count_2 = 0

    for i in range(len(label_list)):
        if label_list[i] == 0:
            count_0 = count_0 + 1
        elif label_list[i] == 1:
            count_1 = count_1 + 1
        else:
            count_2 = count_2 + 1

    curr_label = 0

    if count_0 >= count_1 and count_0 >= count_2:
        curr_label = 0
    elif count_1 > count_0 and count_1 >= count_2:
        curr_label = 1
    else:
        curr_label = 2
    
    if curr_label == sample_v[4]:
        corr = corr + 1

val_acc = (corr / len(val_set))*100
print(K, val_acc)
val_acc_list.append((K ,val_acc))







#L = []
K = 3   #change value of K
corr = 0
for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
       label_list.append(L_sorted[k_value][0][4])
    
    count_0 = 0
    count_1 = 0
    count_2 = 0

    for i in range(len(label_list)):
        if label_list[i] == 0:
            count_0 = count_0 + 1
        elif label_list[i] == 1:
            count_1 = count_1 + 1
        else:
            count_2 = count_2 + 1

    curr_label = 0

    if count_0 >= count_1 and count_0 >= count_2:
        curr_label = 0
    elif count_1 > count_0 and count_1 >= count_2:
        curr_label = 1
    else:
        curr_label = 2
    
    if curr_label == sample_v[4]:
        corr = corr + 1

val_acc = (corr / len(val_set))*100
print(K, val_acc)
val_acc_list.append((K ,val_acc))







#L = []
K = 5  #change value of K
corr = 0
for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
    count_0 = 0
    count_1 = 0
    count_2 = 0

    for i in range(len(label_list)):
        if label_list[i] == 0:
            count_0 = count_0 + 1
        elif label_list[i] == 1:
            count_1 = count_1 + 1
        else:
            count_2 = count_2 + 1

    curr_label = 0

    if count_0 >= count_1 and count_0 >= count_2:
        curr_label = 0
    elif count_1 > count_0 and count_1 >= count_2:
        curr_label = 1
    else:
        curr_label = 2
    
    if curr_label == sample_v[4]:
        corr = corr + 1

val_acc = (corr / len(val_set))*100
print(K, val_acc)
val_acc_list.append((K ,val_acc))







#L = []
K = 8  #change value of K
corr = 0
for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
    count_0 = 0
    count_1 = 0
    count_2 = 0

    for i in range(len(label_list)):
        if label_list[i] == 0:
            count_0 = count_0 + 1
        elif label_list[i] == 1:
            count_1 = count_1 + 1
        else:
            count_2 = count_2 + 1

    curr_label = 0

    if count_0 >= count_1 and count_0 >= count_2:
        curr_label = 0
    elif count_1 > count_0 and count_1 >= count_2:
        curr_label = 1
    else:
        curr_label = 2
    
    if curr_label == sample_v[4]:
        corr = corr + 1

val_acc = (corr / len(val_set))*100
print(K, val_acc)
val_acc_list.append((K ,val_acc))







#L = []
K = 15 #change value of K
corr = 0
for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
       label_list.append(L_sorted[k_value][0][4])
    
    count_0 = 0
    count_1 = 0
    count_2 = 0

    for i in range(len(label_list)):
        if label_list[i] == 0:
            count_0 = count_0 + 1
        elif label_list[i] == 1:
            count_1 = count_1 + 1
        else:
            count_2 = count_2 + 1

    curr_label = 0

    if count_0 >= count_1 and count_0 >= count_2:
        curr_label = 0
    elif count_1 > count_0 and count_1 >= count_2:
        curr_label = 1
    else:
        curr_label = 2
    
    if curr_label == sample_v[4]:
        corr = corr + 1

val_acc = (corr / len(val_set))*100
print(K, val_acc)
val_acc_list.append((K ,val_acc))






#test set



val_acc_list_sorted = sorted(val_acc_list, key = itemgetter(1), reverse = True)
#for i in range(len(val_acc_list_sorted)):
#    print(val_acc_list_sorted[i][0])
K = val_acc_list_sorted[0][0]

#L = []
corr = 0
for sample_test in test_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_test[0]-sample_t[0])**2) + ((sample_test[1]-sample_t[1])**2) + ((sample_test[2]-sample_t[2])**2) + ((sample_test[3]-sample_t[3])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
    count_0 = 0
    count_1 = 0
    count_2 = 0

    for i in range(len(label_list)):
        if label_list[i] == 0:
            count_0 = count_0 + 1
        elif label_list[i] == 1:
            count_1 = count_1 + 1
        else:
            count_2 = count_2 + 1

    curr_label = 0

    if count_0 >= count_1 and count_0 >= count_2:
        curr_label = 0
    elif count_1 > count_0 and count_1 >= count_2:
        curr_label = 1
    else:
        curr_label = 2
    
    if curr_label == sample_test[4]:
        corr = corr + 1

test_acc = (corr / len(test_set))*100

print('Test')

print(K, test_acc)
# Out:
# Classificcation
# 1 90.47619047619048
# 3 95.23809523809523
# 5 100.0
# 8 100.0
# 15 100.0
# Test
# 5 84.21052631578947

# %%
#regression
print('Regression')

import random
from operator import itemgetter

train_set = []
val_set = []
test_set = []
#count = 0
for sample in data_diabetes:
    
    R = random.random()
    if R >= 0 and R <= 0.7:
        train_set.append(sample)
        
    elif R > 0.7 and R <= 0.85:
        val_set.append(sample)
       
    else:
        test_set.append(sample)
    
    #count = count+1
    #print(count)


mse_list = []

#L = []
#for K in range(5, 8, 2):
K = 1   #change value of K
error = 0

for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) + ((sample_v[4]-sample_t[4])**2) + ((sample_v[5]-sample_t[5])**2) + ((sample_v[6]-sample_t[6])**2) + ((sample_v[7]-sample_t[7])**2) + ((sample_v[8]-sample_t[8])**2) + ((sample_v[9]-sample_t[9])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
    # count_0 = 0
    # count_1 = 0
    # count_2 = 0

    # for i in range(len(label_list)):
    #     if label_list[i] == 0:
    #         count_0 = count_0 + 1
    #     elif label_list[i] == 1:
    #         count_1 = count_1 + 1
    #     else:
    #         count_2 = count_2 + 1

    # curr_label = 0

    # if count_0 >= count_1 and count_0 >= count_2:
    #     curr_label = 0
    # elif count_1 > count_0 and count_1 >= count_2:
    #     curr_label = 1
    # else:
    #     curr_label = 2
    
    # if curr_label == sample_v[4]:
    #     corr = corr + 1
    acc = 0
    for i in range(len(label_list)):
        acc = acc + label_list[i]
    
    avg_output = acc / K

    error = error + ( (sample_v[10] - avg_output) )**2


mse = error / len(val_set)
print(K, mse)
mse_list.append((K, mse))


# val_acc = (corr / len(val_set))*100
# val_acc_list.append((K ,val_acc))





#for K in range(5, 8, 2):
K = 3   #change value of K
error = 0

for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) + ((sample_v[4]-sample_t[4])**2) + ((sample_v[5]-sample_t[5])**2) + ((sample_v[6]-sample_t[6])**2) + ((sample_v[7]-sample_t[7])**2) + ((sample_v[8]-sample_t[8])**2) + ((sample_v[9]-sample_t[9])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
   
    acc = 0
    for i in range(len(label_list)):
        acc = acc + label_list[i]
    
    avg_output = acc / K

    error = error + ( (sample_v[10] - avg_output) )**2


mse = error / len(val_set)
print(K, mse)
mse_list.append((K, mse))






#for K in range(5, 8, 2):
K = 5   #change value of K
error = 0

for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) + ((sample_v[4]-sample_t[4])**2) + ((sample_v[5]-sample_t[5])**2) + ((sample_v[6]-sample_t[6])**2) + ((sample_v[7]-sample_t[7])**2) + ((sample_v[8]-sample_t[8])**2) + ((sample_v[9]-sample_t[9])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
   
    acc = 0
    for i in range(len(label_list)):
        acc = acc + label_list[i]
    
    avg_output = acc / K

    error = error + ( (sample_v[10] - avg_output) )**2


mse = error / len(val_set)
print(K, mse)
mse_list.append((K, mse))






#for K in range(5, 8, 2):
K = 10   #change value of K
error = 0

for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) + ((sample_v[4]-sample_t[4])**2) + ((sample_v[5]-sample_t[5])**2) + ((sample_v[6]-sample_t[6])**2) + ((sample_v[7]-sample_t[7])**2) + ((sample_v[8]-sample_t[8])**2) + ((sample_v[9]-sample_t[9])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
    
    acc = 0
    for i in range(len(label_list)):
        acc = acc + label_list[i]
    
    avg_output = acc / K

    error = error + ( (sample_v[10] - avg_output) )**2


mse = error / len(val_set)
print(K, mse)
mse_list.append((K, mse))







#for K in range(5, 8, 2):
K = 15   #change value of K
error = 0

for sample_v in val_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) + ((sample_v[4]-sample_t[4])**2) + ((sample_v[5]-sample_t[5])**2) + ((sample_v[6]-sample_t[6])**2) + ((sample_v[7]-sample_t[7])**2) + ((sample_v[8]-sample_t[8])**2) + ((sample_v[9]-sample_t[9])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    
    
    acc = 0
    for i in range(len(label_list)):
        acc = acc + label_list[i]
    
    avg_output = acc / K

    error = error + ( (sample_v[10] - avg_output) )**2


mse = error / len(val_set)
print(K, mse)
mse_list.append((K, mse))






#test_set



mse_list_sorted = sorted(mse_list, key = itemgetter(1), reverse = False)
K = mse_list_sorted[0][0]



#for K in range(5, 8, 2):
error = 0

for sample_test in test_set:
    L = []
    for sample_t in train_set:
        dist = ( ((sample_test[0]-sample_t[0])**2) + ((sample_test[1]-sample_t[1])**2) + ((sample_test[2]-sample_t[2])**2) + ((sample_test[3]-sample_t[3])**2) + ((sample_test[4]-sample_t[4])**2) + ((sample_test[5]-sample_t[5])**2) + ((sample_test[6]-sample_t[6])**2) + ((sample_test[7]-sample_t[7])**2) + ((sample_test[8]-sample_t[8])**2) + ((sample_test[9]-sample_t[9])**2) )**0.5
        L.append((sample_t,  dist)) 

    L_sorted = sorted(L, key = itemgetter(1), reverse = False)

#for i in range(150):
#    print(L_sorted[i][1])

    label_list = []
    for k_value in range(K):
        label_list.append(L_sorted[k_value][0][4])
    

    acc = 0
    for i in range(len(label_list)):
        acc = acc + label_list[i]
    
    avg_output = acc / K

    error = error + ( (sample_test[10] - avg_output) )**2


mse_test = error / len(train_set)

print('Test')
print(K, mse_test)
# Out:
# Regression
# 1 29288.603444320524
# 3 29288.884257739264
# 5 29288.895162147393
# 10 29289.101048939374
# 15 29289.17798527237
# Test
# 1 6912.65798880483

# %% [markdown]
# Rough (Not part of the algorithm)

# %%
# random.seed(100)
# for i in range(5):
#     print(random.randint(0,1))

# print(random.random())

# for k in range(5, 8, 2):
#   print(k)

# from operator import itemgetter


# li = []

# li.append(([2,3,4], 5))
# li.append(([5,4,2], 3))
# li.append(([1,2,3], 7))
# #li = [[[2, 3, 4], 5], [[5,3,6], 7], [[1,2,3],3]]
# lio = sorted(li, key = itemgetter(1), reverse = False)
# print(lio[2][1])

# print(val_set[0])


# for sample_v in val_set:
#     for sample_t in train_set:
#         dist = ( ((sample_v[0]-sample_t[0])**2) + ((sample_v[1]-sample_t[1])**2) + ((sample_v[2]-sample_t[2])**2) + ((sample_v[3]-sample_t[3])**2) )**0.5
#         print(dist)
#         L.append((sample_t,  dist)) 

# L_sorted = sorted(L, key = itemgetter(1), reverse = False)




# train_set = []
# val_set = []
# test_set = []
# #count = 0
# for sample in data_iris:
#     #random.seed(100)
#     R = random.random()
#     if R >= 0 and R < 0.6:
#         train_set.append(sample)
#         print(1)
        
#     if R > 0.7 and R <= 0.85:
#         #val_set.append(sample)
#         print(2)
       
#     else:
#         test_set.append(sample)
#         print(3)


#print(train_set[56][4])
